# %%
my_list =[ (34329.0, 10004.0, 1.0, 2.0, 87.0, 87.0, 88.0, 86.0),
(34330.0, 10005.0, 1.0, 2.0, 50.0, 50.0, 51.0, 49.0),
(34332.0, 10000, 1.0, 2.0, 67.0, 67.0, 68.0, 66.0),(34332.0, 10004.0, 1.0, 2.0, 67.0, 67.0, 68.0, 66.0),(34332.0, 10000, 1.0, 2.0, 67.0, 67.0, 68.0, 66.0)]

# %%
d ={}

# %%
for i in range(len(my_list)):
    d[str(my_list[i][1])] = [x for x in my_list if x[1]==my_list[i][1]]
    
    print(d)
# Out:
# {'10004.0': [(34329.0, 10004.0, 1.0, 2.0, 87.0, 87.0, 88.0, 86.0), (34332.0, 10004.0, 1.0, 2.0, 67.0, 67.0, 68.0, 66.0)], '10005.0': [(34330.0, 10005.0, 1.0, 2.0, 50.0, 50.0, 51.0, 49.0)], '10000': [(34332.0, 10000, 1.0, 2.0, 67.0, 67.0, 68.0, 66.0), (34332.0, 10000, 1.0, 2.0, 67.0, 67.0, 68.0, 66.0)]}
# {'10004.0': [(34329.0, 10004.0, 1.0, 2.0, 87.0, 87.0, 88.0, 86.0), (34332.0, 10004.0, 1.0, 2.0, 67.0, 67.0, 68.0, 66.0)], '10005.0': [(34330.0, 10005.0, 1.0, 2.0, 50.0, 50.0, 51.0, 49.0)], '10000': [(34332.0, 10000, 1.0, 2.0, 67.0, 67.0, 68.0, 66.0), (34332.0, 10000, 1.0, 2.0, 67.0, 67.0, 68.0, 66.0)]}
# {'10004.0': [(34329.0, 10004.0, 1.0, 2.0, 87.0, 87.0, 88.0, 86.0), (34332.0, 10004.0, 1.0, 2.0, 67.0, 67.0, 68.0, 66.0)], '10005.0': [(34330.0, 10005.0, 1.0, 2.0, 50.0, 50.0, 51.0, 49.0)], '10000': [(34332.0, 10000, 1.0, 2.0, 67.0, 67.0, 68.0, 66.0), (34332.0, 10000, 1.0, 2.0, 67.0, 67.0, 68.0, 66.0)]}
# ...

# %%
print(new_list)
# Out:
# [[34330.0, 10005.0, 1.0, 2.0, 50.0, 50.0, 51.0, 49.0], [34332.0, 10000, 1.0, 2.0, 67.0, 67.0, 68.0, 66.0]]

# %%
print(new)
# Out:
# None

# %%
print(d['10000'])
# Out:
# [(34332.0, 10000, 1.0, 2.0, 67.0, 67.0, 68.0, 66.0), (34332.0, 10000, 1.0, 2.0, 67.0, 67.0, 68.0, 66.0)]
